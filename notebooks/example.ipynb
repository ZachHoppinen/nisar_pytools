# %%
from nisar_pytools import open_nisar

# %%
dt = open_nisar('/Users/zmhoppinen/Documents/nisar_pytools/local/gslcs/NISAR_L2_PR_GSLC_004_077_A_024_4005_DHDH_A_20251103T124615_20251103T124650_X05009_N_F_J_001.h5')

# %%
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       Conventions:         CF-1.7
# │       contact:             nisar-sds-ops@jpl.nasa.gov
# │       institution:         NASA JPL
# │       mission_name:        NISAR
# │       reference_document:  D-102269 NISAR NASA SDS Product Specification Level-...
# │       title:               NISAR L2 GSLC Product
# │       product_type:        GSLC
# └── Group: /science
#     └── Group: /science/LSAR
#         ├── Group: /science/LSAR/identification
#         │       Attributes: (12/34)
#         │           absoluteOrbitNumber:          1387
#         │           boundingPolygon:              POLYGON ((-114.84833966609 43.8385438384514...
#         │           compositeReleaseId:           X05009
#         │           diagnosticModeFlag:           0
#         │           frameNumber:                  24
#         │           granuleId:                    NISAR_L2_PR_GSLC_004_077_A_024_4005_DHDH_A_...
# ...
